# %%
from deep_translator import GoogleTranslator

# %%
text = "hello! how are you?"
translator = GoogleTranslator(source='en', target='ne')
print(translator.translate(text))
# Out:
# नमस्कार! तिमी कस्तो छौ
